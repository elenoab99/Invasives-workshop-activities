# %% [markdown]
# # Activity 7 — Fit the Random Forest
#
# **Goal:** Reproduce the source notebook's class/observation split and model fitting.

# %% [markdown]
# > 🟢 **Follow Me** — run and understand a working example.
# > 🟡 **Your Turn** — complete or modify part of the code.
# > 🔵 **Challenge** — work out the solution from earlier examples.
# > 🔎 **Debug It** — diagnose an error or unexpected result.
# >
# > This version follows the uploaded **Fiji_cordia_2.0_prediction_Vanuatu** workflow, while breaking complex lines into beginner-friendly steps.

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## 7.1 🟡 Your Turn — Separate labels and observations
# The source workflow stores classes in the first column and predictors in all remaining columns.

# %%
classes = np.array(training_array)[:, ___]

observations = np.array(training_array)[:, ___:]

print(classes.shape)
print(observations.shape)

# %% [markdown]
# ## 7.2 🟢 Follow Me — Create the classifier

# %%
classifier = RandomForestClassifier(random_state=42)

# %% [markdown]
# ## 7.3 🟡 Your Turn — Fit the model

# %%
model = classifier.fit(__________, __________)

# %% [markdown]
# ## 7.4 🔵 Challenge
# Print the unique class labels and the number of predictor columns. Explain what one row of `observations` represents.

# %%
# CHALLENGE
