# %% [markdown]
# # Activity 2 — Lists, Conditions and Functions
#
# **Goal:** Learn Python structures that appear later in masking and classification.

# %% [markdown]
# > 🟢 **Follow Me** — run and understand a working example.
# > 🟡 **Your Turn** — complete or modify part of the code.
# > 🔵 **Challenge** — work out the solution from earlier examples.
# > 🔎 **Debug It** — diagnose an error or unexpected result.
# >
# > This version follows the uploaded **Fiji_cordia_2.0_prediction_Vanuatu** workflow, while breaking complex lines into beginner-friendly steps.

# %% [markdown]
# ## 2.1 🟢 Follow Me — Lists

# %%
bands = ["red", "green", "blue"]
print(bands)

# %% [markdown]
# ## 2.2 🟡 Your Turn
# Complete the Sentinel-2 measurement list used by the prediction workflow.

# %%
measurements = [
    "red",
    "green",
    "blue",
    # add nir08, swir16 and scl
]
print(measurements)

# %% [markdown]
# ## 2.3 🟢 Follow Me — Boolean conditions

# %%
cloud_cover = 18
print(cloud_cover < 25)

# %% [markdown]
# ## 2.4 🟡 Your Turn
# Test whether a cloud-cover value of 35 passes a threshold of 25.

# %%
cloud_cover = 35
threshold = 25

# YOUR TURN

# %% [markdown]
# ## 2.5 🔵 Challenge
# Create a list containing the SCL values 1, 3, 9 and 10.

# %%
mask_flags = [
    # YOUR TURN
]
