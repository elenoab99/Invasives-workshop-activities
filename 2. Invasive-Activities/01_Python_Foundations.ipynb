# %% [markdown]
# # Activity 1 — Python Foundations for Invasive-Species Detection
#
# **Goal:** Read, run and modify simple Python before using the EO workflow.

# %% [markdown]
# > 🟢 **Follow Me** — run and understand a working example.
# > 🟡 **Your Turn** — complete or modify part of the code.
# > 🔵 **Challenge** — work out the solution from earlier examples.
# > 🔎 **Debug It** — diagnose an error or unexpected result.
# >
# > This version follows the uploaded **Fiji_cordia_2.0_prediction_Vanuatu** workflow, while breaking complex lines into beginner-friendly steps.

# %% [markdown]
# ## 1.1 🟢 Follow Me

# %%
target_species = "Cordia alliodora"
print(target_species)
# Out:
# Cordia alliodora

# %% [markdown]
# ## 1.2 🟡 Your Turn
# Create variables for `country`, `year`, and `cloud_threshold`.

# %%
country = ""
year = 0
cloud_threshold = 0

print(country, year, cloud_threshold)

# %% [markdown]
# ## 1.3 🔎 Debug It
# Correct the variable name.

# %%
print(Target_species)

# %% [markdown]
# ## 1.4 🔵 Challenge
# Print a sentence using the variables rather than retyping their values.

# %%
# CHALLENGE

# %%
print ("Take Away", target_species)
