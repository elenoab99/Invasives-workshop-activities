# %% [markdown]
# # Activity 3 — AOI and Field Training Data
#
# **Goal:** Load the same kinds of AOI and training-point files used in the Cordia/Vanuatu workflow.

# %% [markdown]
# > 🟢 **Follow Me** — run and understand a working example.
# > 🟡 **Your Turn** — complete or modify part of the code.
# > 🔵 **Challenge** — work out the solution from earlier examples.
# > 🔎 **Debug It** — diagnose an error or unexpected result.
# >
# > This version follows the uploaded **Fiji_cordia_2.0_prediction_Vanuatu** workflow, while breaking complex lines into beginner-friendly steps.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# ## 3.1 🟡 Your Turn — Load the AOI
# The source workflow uses `AOI/EfateAOI.geojson`.

# %%
AOI_PATH = "../data/EfateAOI.geojson"
aoi_gdf = gpd.read_file(__________)

aoi_gdf.plot(edgecolor="red", facecolor="none")
plt.title("AOI Check")
plt.show()

# %% [markdown]
# ## 3.2 🟢 Follow Me — Bounding box

# %%
bbox = aoi_gdf.total_bounds
print("bbox:", bbox)

# %% [markdown]
# ## 3.3 🟡 Your Turn — Inspect geometry and CRS

# %%
# YOUR TURN
# Print the CRS, geometry types and feature count.

# %% [markdown]
# ## 3.4 🟡 Your Turn — Load field/training points
# The source workflow expects a numeric class field called `randomforest`.

# %%
TRAINING_PATH = "../data/Merged_CleanV3.geojson"
gdf = gpd.read_file(__________, bbox=tuple(bbox))

gdf.explore(column="randomforest", legend=True)

# %% [markdown]
# ## 3.5 🔵 Challenge
# Use `value_counts()` to find how many training points belong to each `randomforest` class.

# %%
# CHALLENGE
