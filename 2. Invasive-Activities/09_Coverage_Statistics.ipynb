# %% [markdown]
# # Activity 9 — Calculate Invasive-Species Coverage
#
# **Goal:** Extend the source prediction output into an interpretable area/coverage result.

# %% [markdown]
# > 🟢 **Follow Me** — run and understand a working example.
# > 🟡 **Your Turn** — complete or modify part of the code.
# > 🔵 **Challenge** — work out the solution from earlier examples.
# > 🔎 **Debug It** — diagnose an error or unexpected result.
# >
# > This version follows the uploaded **Fiji_cordia_2.0_prediction_Vanuatu** workflow, while breaking complex lines into beginner-friendly steps.

# %% [markdown]
# This coverage calculation is a workshop extension after the source notebook's prediction/export stage.

# %% [markdown]
# ## 9.1 🟢 Follow Me — Pixel size

# %%
resolution_x = abs(float(predicted_da.odc.geobox.resolution.x))
resolution_y = abs(float(predicted_da.odc.geobox.resolution.y))

pixel_area_m2 = resolution_x * resolution_y

print("Pixel area:", pixel_area_m2, "m²")

# %% [markdown]
# ## 9.2 🟡 Your Turn — Choose the Cordia class ID
# Use the same numeric label used in the `randomforest` training field.

# %%
CORDIA_CLASS = ___

# %% [markdown]
# ## 9.3 🟡 Your Turn — Count pixels and calculate hectares

# %%
cordia_pixels = int((predicted_da == CORDIA_CLASS).sum().item())

cordia_area_m2 = ______________________________
cordia_area_ha = ______________________________

print("Cordia pixels:", cordia_pixels)
print("Cordia area:", cordia_area_ha, "ha")

# %% [markdown]
# ## 9.4 🔵 Challenge — Percentage coverage
# Calculate the percentage of mapped pixels classified as Cordia.

# %%
# CHALLENGE

# %% [markdown]
# ## 9.5 Discussion
# How does converting a classification to hectares make the result more useful for management, monitoring and control planning?
